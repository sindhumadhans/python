# %%
from multiplefunctions import subfieldsinai

# %%
subfieldsinai.subfields()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 subfieldsinai.subfields()
#
# TypeError: subfieldsinai.subfields() missing 1 required positional argument: 'self'
