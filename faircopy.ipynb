# %%
from multiplefunctions import subfieldsinai

# %%
subfieldsinai.subfields()
# Out:
# subfields in ai are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
subfieldsinai.odd_even(8)
# Out:
# 8 is even

# %%
 subfieldsinai.eligible()
# Out:
# enter the gender male
# enter the age 18
# not eligible to marry

# %%
 subfieldsinai.Percentage()
# Out:
# Enter mark for subject 0:  100
# Enter mark for subject 1:  100
# Enter mark for subject 2:  100
# Enter mark for subject 3:  100
# Enter mark for subject 4:  100
# [100, 100, 100, 100, 100]
# 100.0

# %%
 subfieldsinai.area(6,4)
# Out:
# Area of triangle: 12.0

# %%
  subfieldsinai.perimeter(2,2,4)
# Out:
# Perimeter of triangle: 8
